# %%
import pandas as pd
df = pd.read_csv('C://Users//47129//Desktop//bank-additional-full.csv',sep=';')

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
df.describe()
df.isnull().any()
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
import matplotlib
from matplotlib import pyplot as plt
pd.value_counts(df['y'],normalize=True).plot.bar(color='gray')
plt.ylabel('count')
plt.show()

# %%
# draw on the figure, define the properties of the line or marker
df['age'].hist(bins=40,grid=True)

# modify the properties of the figure
# axis labels, title, x and y limits, etc.
plt.xlabel('age')
plt.ylabel('counts')
plt.title('age distribution')
plt.tight_layout()
# show the figure in the notebook or save it as a file
plt.show()

# %%
df[['age','y']].boxplot(by='y')
plt.ylabel('age')
plt.show()

# %%
import seaborn as sns
sns.countplot(y='job', hue='y', data=df, order = df['job'].value_counts().index)

# %%
sns.catplot(y="job", col="y", data=df, kind="count",
              height=4, aspect=.7,order = df['job'].value_counts().index);

# %%
count_matrix = df.groupby(['job', 'y']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
print(count_matrix_norm)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()
# Out:
# y                    no       yes
# job
# admin.         0.870274  0.129726
# blue-collar    0.931057  0.068943
# entrepreneur   0.914835  0.085165
# housemaid      0.900000  0.100000
# management     0.887825  0.112175
# retired        0.747674  0.252326
# self-employed  0.895144  0.104856
# services       0.918619  0.081381
# student        0.685714  0.314286
# technician     0.891740  0.108260
# unemployed     0.857988  0.142012
# unknown        0.887879  0.112121

# %%
sns.countplot(y='marital', hue='y', data=df, order = df['marital'].value_counts().index)

count_matrix = df.groupby(['marital', 'y']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()

# %%
sns.countplot(y='education', hue='y', data=df, order = df['education'].value_counts().index)

count_matrix = df.groupby(['education', 'y']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()

# %%
sns.countplot(y='default', hue='y', data=df, order = df['default'].value_counts().index)

count_matrix = df.groupby(['default', 'y']).size().unstack()
print(count_matrix)
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()
# Out:
# y             no     yes
# default
# no       28391.0  4197.0
# unknown   8154.0   443.0
# yes          3.0     NaN

# %%
sns.countplot(y='housing', hue='y', data=df, order = df['housing'].value_counts().index)

count_matrix = df.groupby(['housing', 'y']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()

# %%
sns.countplot(y='loan', hue='y', data=df, order = df['loan'].value_counts().index)

count_matrix = df.groupby(['loan', 'y']).size().unstack()
print(count_matrix)
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()
# Out:
# y           no   yes
# loan
# no       30100  3850
# unknown    883   107
# yes       5565   683

# %%
sns.countplot(y='contact', hue='y', data=df, order = df['contact'].value_counts().index)

count_matrix = df.groupby(['contact', 'y']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()

# %%
sns.countplot(y='month', hue='y', data=df,order =['mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])

count_matrix = df.groupby(['month', 'y']).size().unstack()
print(count_matrix)
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()
# Out:
# y         no  yes
# month
# apr     2093  539
# aug     5523  655
# dec       93   89
# jul     6525  649
# jun     4759  559
# mar      270  276
# may    12883  886
# nov     3685  416
# oct      403  315
# sep      314  256

# %%
sns.countplot(y='day_of_week', hue='y', data=df, order = df['day_of_week'].value_counts().index)

count_matrix = df.groupby(['day_of_week', 'y']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 8)
sns.countplot(x = 'duration', data = df)
ax.set_xlabel('duration', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('Duration Count Distribution', fontsize=15)
sns.despine()

# %%
# draw on the figure, define the properties of the line or marker
df['duration'].hist(bins=5000,grid=True)

# modify the properties of the figure
# axis labels, title, x and y limits, etc.
plt.xlabel('duration')
plt.ylabel('counts')
plt.title('duration distribution')
plt.tight_layout()
# show the figure in the notebook or save it as a file
plt.show()
df[['duration','y']].boxplot(by='y')
plt.ylabel('duration')
plt.show()

# %%
# draw on the figure, define the properties of the line or marker
df['campaign'].hist(bins=56,grid=True)

# modify the properties of the figure
# axis labels, title, x and y limits, etc.
plt.xlabel('campaign')
plt.ylabel('counts')
plt.title('campaign distribution')
plt.tight_layout()
# show the figure in the notebook or save it as a file
plt.show()
df[['campaign','y']].boxplot(by='y')
plt.ylabel('campaign')
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 8)
sns.countplot(x = 'campaign', data = df,palette='coolwarm')
ax.set_xlabel('campaign', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('Campaign Count Distribution', fontsize=15)
sns.despine()

# %%
pd.value_counts(df['pdays'],normalize=True).plot.bar(color='blue')
plt.ylabel('count')
plt.show()

count_matrix = df.groupby(['pdays', 'y']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()

# %%
pd.value_counts(df['previous'],normalize=True).plot.bar()
plt.ylabel('count')
plt.show()

count_matrix = df.groupby(['previous', 'y']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()

# %%
pd.value_counts(df['poutcome'],normalize=True).plot.bar()
plt.ylabel('count')
plt.show()

count_matrix = df.groupby(['poutcome', 'y']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)
count_matrix_norm.plot(kind='bar', stacked=True)
plt.ylabel('fraction of people in group')
plt.legend(loc=4)
plt.show()

# %%
dataset = [df[df['y']=='no']['emp.var.rate'].values,
           df[df['y']=='yes']['emp.var.rate'].values]

plt.violinplot(dataset = dataset)
plt.xticks([1,2],['no','yes'])
plt.xlabel('y')
plt.ylabel('emp.var.rate')
plt.show()
df[['emp.var.rate','y']].boxplot(by='y')
plt.ylabel('emp.var.rate')
plt.show()

# %%
dataset = [df[df['y']=='no']['cons.price.idx'].values,
           df[df['y']=='yes']['cons.price.idx'].values]

plt.violinplot(dataset = dataset)
plt.xticks([1,2],['no','yes'])
plt.xlabel('y')
plt.ylabel('cons.price.idx')
plt.show()
df[['cons.price.idx','y']].boxplot(by='y')
plt.ylabel('cons.price.idx')
plt.show()

# %%
df[['cons.conf.idx','y']].boxplot(by='y')
plt.ylabel('cons.conf.idx')
plt.show()

# %%
df[['euribor3m','y']].boxplot(by='y')
plt.ylabel('euribor3m')
plt.show()

# %%
df[['nr.employed','y']].boxplot(by='y')
plt.ylabel('nr.employed')
plt.show()

# %%
df['pdays']
# Out:
# 0        999
# 1        999
# 2        999
# 3        999
# 4        999
# 5        999
# 6        999
# 7        999
# 8        999
# 9        999
# 10       999
# 11       999
# 12       999
# 13       999
# 14       999
# 15       999
# 16       999
# 17       999
# 18       999
# 19       999
# 20       999
# 21       999
# 22       999
# 23       999
# 24       999
# 25       999
# 26       999
# 27       999
# 28       999
# 29       999
#         ...
# 41158    999
# 41159      9
# 41160    999
# 41161    999
# 41162      4
# 41163      4
# 41164     10
# 41165    999
# 41166    999
# 41167    999
# 41168    999
# 41169    999
# 41170    999
# 41171    999
# 41172    999
# 41173    999
# 41174      1
# 41175    999
# 41176    999
# 41177    999
# 41178      6
# 41179    999
# 41180    999
# 41181    999
# 41182      9
# 41183    999
# 41184    999
# 41185    999
# 41186    999
# 41187    999
# Name: pdays, Length: 41188, dtype: int64

# %%
df['pdayscon'] = df.pdays.apply(lambda s: 0 if s == 999 else 1)
df
# Out:
#        age            job   marital            education  default  housing  \
# 0       56      housemaid   married             basic.4y       no       no
# 1       57       services   married          high.school  unknown       no
# 2       37       services   married          high.school       no      yes
# 3       40         admin.   married             basic.6y       no       no
# 4       56       services   married          high.school       no       no
# 5       45       services   married             basic.9y  unknown       no
# 6       59         admin.   married  professional.course       no       no
# 7       41    blue-collar   married              unknown  unknown       no
# 8       24     technician    single  professional.course       no      yes
# 9       25       services    single          high.school       no      yes
# 10      41    blue-collar   married              unknown  unknown       no
# ...

# %%
df['pdayscon'].value_counts(0)
# Out:
# 0    39673
# 1     1515
# Name: pdayscon, dtype: int64

# %%
labels=['no','yes']  
X=[39673,1515]    
fig = plt.figure()  
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）  
plt.title("Previously contacted?")  
plt.show()

# %%
cat_ftrs = ['job','marital','education','default','housing','loan','contact','poutcome','month','day_of_week']
num_ftrs = ['pdayscon','age','campaign','previous','duration','cons.price.idx','cons.conf.idx','euribor3m']

# %%
pd.plotting.scatter_matrix(df[num_ftrs],c = le, figsize=(15, 15), marker='o',
                           hist_kwds={'bins': 20}, s=60, alpha=.8)
plt.show()

# %%
pd.plotting.scatter_matrix(df[['age','campaign','previous','duration']],c = le, figsize=(15, 15), marker='o',
                           hist_kwds={'bins': 20}, s=60, alpha=.8)
plt.show()

# %%
marketing_df=df[['emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed']]
corr=marketing_df.corr()
corr
# Out:
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# emp.var.rate        1.000000        0.775334       0.196041   0.972245
# cons.price.idx      0.775334        1.000000       0.058986   0.688230
# cons.conf.idx       0.196041        0.058986       1.000000   0.277686
# euribor3m           0.972245        0.688230       0.277686   1.000000
# nr.employed         0.906970        0.522034       0.100513   0.945154
#
#                 nr.employed
# emp.var.rate       0.906970
# cons.price.idx     0.522034
# cons.conf.idx      0.100513
# euribor3m          0.945154
# nr.employed        1.000000

# %%
sns.set_context("notebook",font_scale = 1.5, rc = {"lines.linewidth":2.5})
plt.figure(figsize = (13,9))
a = sns.heatmap(corr, annot = True, fmt = ".3f")

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
ohe = OneHotEncoder(sparse=False)
si = SimpleImputer(strategy='constant',fill_value='missing')
cat_values = ohe.fit_transform(si.fit_transform(df[cat_ftrs]))
cat_ftr_names = ohe.get_feature_names(['job','marital','education','default','housing','loan','contact','poutcome','month','day_of_week'])
df_cat = pd.DataFrame(data=cat_values,columns = cat_ftr_names)


# standard scaler
ss = StandardScaler()
num_values = ss.fit_transform(df[num_ftrs])
df_num = pd.DataFrame(data=num_values,columns = num_ftrs)

df_preprocessed_features = pd.concat([df_cat,df_num],axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
print(df_cat.shape)
print(df_num.shape)
print(df_preprocessed_features.shape)
# Out:
# (41188, 53)
# (41188, 8)
# (41188, 61)

# %%
from sklearn.preprocessing import LabelEncoder
y=df[['y']]
enc = LabelEncoder()
le = enc.fit_transform(y)
print(le.shape)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# (41188,)

# %%
df_preprocessed_features.columns
# Out:
# Index(['job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_divorced', 'marital_married', 'marital_single',
#        'marital_unknown', 'education_basic.4y', 'education_basic.6y',
#        'education_basic.9y', 'education_high.school', 'education_illiterate',
#        'education_professional.course', 'education_university.degree',
#        'education_unknown', 'default_no', 'default_unknown', 'default_yes',
#        'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
#        'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
#        'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success',
#        'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun',
#        'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
# ...

# %%
df_preprocessed_features.shape
# Out:
# (41188, 61)

# %%
import numpy as np
X = df_preprocessed_features
y = le
classes, counts = np.unique(y,return_counts=True)
print('balance:',np.max(counts/len(y)))
# Out:
# balance: 0.8873458288821987

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
def ML_pipeline_kfold_GridSearchCV(X,y,random_state,n_folds):
    # create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state = random_state,stratify=y)
    # splitter for _other
    kf = StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=random_state)
    # create the pipeline: preprocessor + supervised ML method
    scaler = StandardScaler()
    pipe = make_pipeline(scaler,SVC())
    # the parameter(s) we want to tune
    param_grid = {'svc__C': np.logspace(0,1,num=2),'svc__gamma': np.logspace(-1,0,num=2)}
    # prepare gridsearch
    grid = GridSearchCV(pipe, param_grid=param_grid,scoring = make_scorer(accuracy_score),
                        cv=kf, return_train_score = True,iid=True)
    # do kfold CV on _other
    grid.fit(X_other, y_other)
    return grid, grid.score(X_test, y_test)

# %%
test_scores = []
for i in range(3):
    grid, test_score = ML_pipeline_kfold_GridSearchCV(X,y,i*42,5)
    print(grid.best_params_)
    print('best CV score:',grid.best_score_)
    print('test score:',test_score)
    test_scores.append(test_score)
print('test accuracy:',np.around(np.mean(test_scores),2),'+/-',np.around(np.std(test_scores),2))
# Out:
# {'svc__C': 1.0, 'svc__gamma': 0.1}
# best CV score: 0.8911684370257966
# test score: 0.8895362952172857
# {'svc__C': 1.0, 'svc__gamma': 0.1}
# best CV score: 0.8900455235204856
# test score: 0.894027676620539
# {'svc__C': 1.0, 'svc__gamma': 0.1}
# best CV score: 0.8916236722306525
# test score: 0.8900218499635834
# test accuracy: 0.89 +/- 0.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
def ML_pipeline_kfold_GridSearchCV(X,y,random_state,n_folds):
    # create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state = random_state,stratify=y)
    # splitter for _other
    kf = StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=random_state)
    # create the pipeline: preprocessor + supervised ML method
    scaler = StandardScaler()
    pipe = make_pipeline(scaler,SVC())
    # the parameter(s) we want to tune
    param_grid = {'svc__C': np.logspace(0,1,num=2),'svc__gamma': np.logspace(-1,0,num=2)}
    # prepare gridsearch
    grid = GridSearchCV(pipe, param_grid=param_grid,scoring = make_scorer(recall_score),
                        cv=kf, return_train_score = True,iid=True)
    # do kfold CV on _other
    grid.fit(X_other, y_other)
    return grid, grid.score(X_test, y_test)
test_scores = []
for i in range(3):
    grid, test_score = ML_pipeline_kfold_GridSearchCV(X,y,i*42,5)
    print(grid.best_params_)
    print('best CV score:',grid.best_score_)
    print('test score:',test_score)
    test_scores.append(test_score)
print('test recall:',np.around(np.mean(test_scores),2),'+/-',np.around(np.std(test_scores),2))
# Out:
# {'svc__C': 10.0, 'svc__gamma': 0.1}
# best CV score: 0.23141515673801297
# test score: 0.22844827586206898
# {'svc__C': 10.0, 'svc__gamma': 0.1}
# best CV score: 0.21714099625605804
# test score: 0.27478448275862066
# {'svc__C': 10.0, 'svc__gamma': 0.1}
# best CV score: 0.23895198394044345
# test score: 0.25
# test recall: 0.25 +/- 0.02

# %%
y.sum()
# Out:
# 4640

# %%
X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state = 5,stratify=y)
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [0.1],
                     'C': [1]},
                    {'kernel': ['linear'], 'C': [1]}]

clf = GridSearchCV(SVC(), tuned_parameters, cv=5, scoring=make_scorer(accuracy_score))
clf.fit(X_other, y_other)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'kernel': ['rbf'], 'gamma': [0.1], 'C': [1]}, {'kernel': ['linear'], 'C': [1]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(accuracy_score), verbose=0)

# %%
print('The best model is: ', clf.best_params_)
print('This model produces a mean cross-validated score (precision) of', clf.best_score_)
# Out:
# The best model is:  {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# This model produces a mean cross-validated score (precision) of 0.9105007587253414

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
def ML_pipeline_kfold_GridSearchCV(X,y,random_state,n_folds):
    # create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state = random_state,stratify=y)
    # splitter for _other
    kf = StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=random_state)
    # create the pipeline: preprocessor + supervised ML method
    pipe = RandomForestClassifier(random_state=10)
    # the parameter(s) we want to tune
    param_grid = {'n_estimators': np.int64(np.logspace(0,2,num=4)),'max_depth': np.linspace(5,11,num=4)}
    # prepare gridsearch
    grid = GridSearchCV(pipe, param_grid=param_grid,scoring = make_scorer(accuracy_score),
                        cv=kf, return_train_score = True,iid=True)
    # do kfold CV on _other
    grid.fit(X_other, y_other)
    return grid, grid.score(X_test, y_test)

# %%
test_scores = []
for i in range(5):
    grid, test_score = ML_pipeline_kfold_GridSearchCV(X,y,i*42,5)
    print(grid.best_params_)
    print('best CV score:',grid.best_score_)
    print('test score:',test_score)
    test_scores.append(test_score)
print('test accuracy:',np.around(np.mean(test_scores),2),'+/-',np.around(np.std(test_scores),4))
# Out:
# {'max_depth': 11.0, 'n_estimators': 100}
# best CV score: 0.9093474962063733
# test score: 0.9061665452779801
# {'max_depth': 11.0, 'n_estimators': 21}
# best CV score: 0.9065553869499241
# test score: 0.9136926438455936
# {'max_depth': 11.0, 'n_estimators': 100}
# best CV score: 0.9074355083459787
# test score: 0.9084729303228939
# {'max_depth': 11.0, 'n_estimators': 21}
# best CV score: 0.90701062215478
# test score: 0.9099295945617868
# {'max_depth': 11.0, 'n_estimators': 21}
# best CV score: 0.9074658573596358
# test score: 0.9101723719349356
# test accuracy: 0.91 +/- 0.0025

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 1,stratify=y)
clf = RandomForestClassifier(n_estimators=21,max_depth=11,random_state=1)
clf.fit(X_train,y_train)
pred = clf.predict(X_test)
accuracy=accuracy_score(y_test, pred)
f1=f1_score(y_test, pred)
recall=recall_score(y_test,pred)

print(accuracy)
print(f1)
print(recall)
# Out:
# 0.9100509832483612
# 0.44660194174757284
# 0.32219827586206895

# %%
def ML_pipeline_kfold_GridSearchCV(X,y,random_state,n_folds):
    # create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state = random_state,stratify=y)
    # splitter for _other
    kf = StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=random_state)
    # create the pipeline: preprocessor + supervised ML method
    pipe = RandomForestClassifier(random_state=10)
    # the parameter(s) we want to tune
    param_grid = {'n_estimators': np.int64(np.logspace(0,2,num=4)),'max_depth': np.linspace(5,11,num=4)}
    # prepare gridsearch
    grid = GridSearchCV(pipe, param_grid=param_grid,scoring = make_scorer(recall_score),
                        cv=kf, return_train_score = True,iid=True)
    # do kfold CV on _other
    grid.fit(X_other, y_other)
    return grid, grid.score(X_test, y_test)
test_scores = []
for i in range(5):
    grid, test_score = ML_pipeline_kfold_GridSearchCV(X,y,i*42,5)
    print(grid.best_params_)
    print('best CV score:',grid.best_score_)
    print('test score:',test_score)
    test_scores.append(test_score)
print('test accuracy:',np.around(np.mean(test_scores),2),'+/-',np.around(np.std(test_scores),4))
# Out:
# {'max_depth': 9.0, 'n_estimators': 1}
# best CV score: 0.32328671996500274
# test score: 0.2683189655172414
# {'max_depth': 11.0, 'n_estimators': 4}
# best CV score: 0.28529357182021975
# test score: 0.3103448275862069
# {'max_depth': 11.0, 'n_estimators': 1}
# best CV score: 0.32813709074438535
# test score: 0.2683189655172414
# {'max_depth': 11.0, 'n_estimators': 1}
# best CV score: 0.3038677017162288
# test score: 0.4515086206896552
# {'max_depth': 9.0, 'n_estimators': 1}
# best CV score: 0.2973932882794018
# test score: 0.3459051724137931
# test accuracy: 0.33 +/- 0.0678

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 1,stratify=y)
clf = RandomForestClassifier(n_estimators=1,max_depth=11,random_state=1)
clf.fit(X_train,y_train)
pred = clf.predict(X_test)
accuracy=accuracy_score(y_test, pred)
f1=f1_score(y_test, pred)
recall=recall_score(y_test,pred)

print(accuracy)
print(f1)
print(recall)
# Out:
# 0.898761835396941
# 0.4520367936925099
# 0.3706896551724138

# %%
# Out:
# (61,)

# %%
importances = clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")
for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature 57 (0.403401)
# 2. feature 53 (0.127259)
# 3. feature 56 (0.083247)
# 4. feature 60 (0.067704)
# 5. feature 54 (0.036616)
# 6. feature 43 (0.029759)
# 7. feature 38 (0.025773)
# 8. feature 59 (0.024973)
# 9. feature 55 (0.021432)
# 10. feature 46 (0.019433)
# 11. feature 58 (0.017572)
# 12. feature 47 (0.014156)
# 13. feature 24 (0.010375)
# 14. feature 44 (0.007892)
# 15. feature 14 (0.006699)
# 16. feature 33 (0.006324)
# 17. feature 34 (0.005385)
# 18. feature 27 (0.004606)
# 19. feature 19 (0.004563)
# 20. feature 17 (0.004218)
# 21. feature 9 (0.004123)
# 22. feature 39 (0.003965)
# 23. feature 6 (0.003831)
# 24. feature 29 (0.003748)
# 25. feature 49 (0.003741)
# 26. feature 32 (0.003476)
# 27. feature 16 (0.003428)
# 28. feature 0 (0.003425)
# 29. feature 37 (0.003223)
# 30. feature 18 (0.003131)
# 31. feature 5 (0.003031)
# 32. feature 50 (0.002746)
# 33. feature 1 (0.002692)
# 34. feature 51 (0.002650)
# 35. feature 30 (0.002561)
# ...

# %%
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()

# %%
import numpy as np
xp = ['duration','pdayscon','previous','euribor3m','age','month_mar','month_apr','cons.conf.idx','campaign','month_oct','cons.price.idx','month_sep','default_no','month_may','marital_single']
yp = [0.403401,0.127259,0.083247,0.067704,0.036616,0.029759,0.025773,0.024973,0.021432,0.019433,0.017572,0.014156,0.010375,0.007892,0.006699]

width =0.25
plt.barh(xp,yp,width,color='b')
plt.xlabel('Importances',color='black')
plt.ylabel('Features',color='black')
plt.title('Feature Importance')
plt.gca().invert_yaxis()
plt.show()

# %%
ss = StandardScaler()
num_values = ss.fit_transform(df[num_ftrs])
df_num = pd.DataFrame(data=num_values,columns = num_ftrs)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
ftrs=['job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
       'job_management', 'job_retired', 'job_self-employed', 'job_services',
       'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'education_basic.4y', 'education_basic.6y',
       'education_basic.9y', 'education_high.school', 'education_illiterate',
       'education_professional.course', 'education_university.degree',
       'education_unknown', 'default_no', 'default_unknown', 'default_yes',
       'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
       'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
       'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success',
       'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun',
       'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
       'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu',
       'day_of_week_tue', 'day_of_week_wed', 'pdayscon', 'age', 'campaign',
       'previous', 'duration', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m']
scaler = StandardScaler()
values = scaler.fit_transform(X)
X_s = pd.DataFrame(data=values,columns = ftrs)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

def ML_pipeline_kfold_GridSearchCV(X_s,y,random_state,n_folds):
    # create a test set
    X_other, X_test, y_other, y_test = train_test_split(X_s, y, test_size=0.2, random_state = random_state,stratify=y)
    # splitter for _other
    kf = StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=random_state)
    # create the pipeline: preprocessor + supervised ML method
    pipe = LogisticRegression()
    # the parameter(s) we want to tune
    param_grid = {'C': np.logspace(-1,1,num=3),'penalty': ['l1','l2']}
    # prepare gridsearch
    grid = GridSearchCV(pipe, param_grid=param_grid,scoring = make_scorer(accuracy_score),
                        cv=kf, return_train_score = True,iid=True)
    # do kfold CV on _other
    grid.fit(X_other, y_other)
    return grid, grid.score(X_test, y_test)

# %%
test_scores = []
for i in range(5):
    grid, test_score = ML_pipeline_kfold_GridSearchCV(X_s,y,i*42,5)
    print(grid.best_params_)
    print('best CV score:',grid.best_score_)
    print('test score:',test_score)
    test_scores.append(test_score)
print('test accuracy:',np.around(np.mean(test_scores),2),'+/-',np.around(np.std(test_scores),4))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
def ML_pipeline_kfold_GridSearchCV(X_s,y,random_state,n_folds):
    # create a test set
    X_other, X_test, y_other, y_test = train_test_split(X_s, y, test_size=0.2, random_state = random_state,stratify=y)
    # splitter for _other
    kf = StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=random_state)
    # create the pipeline: preprocessor + supervised ML method
    pipe = LogisticRegression()
    # the parameter(s) we want to tune
    param_grid = {'C': np.logspace(-1,1,num=3),'penalty': ['l1','l2']}
    # prepare gridsearch
    grid = GridSearchCV(pipe, param_grid=param_grid,scoring = make_scorer(recall_score),
                        cv=kf, return_train_score = True,iid=True)
    # do kfold CV on _other
    grid.fit(X_other, y_other)
    return grid, grid.score(X_test, y_test)
test_scores = []
for i in range(5):
    grid, test_score = ML_pipeline_kfold_GridSearchCV(X,y,i*42,5)
    print(grid.best_params_)
    print('best CV score:',grid.best_score_)
    print('test score:',test_score)
    test_scores.append(test_score)
print('test recall_score:',np.around(np.mean(test_scores),2),'+/-',np.around(np.std(test_scores),4))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 1,stratify=y)
clf = LogisticRegression(C=1,penalty='l2')
clf.fit(X_train,y_train)
pred = clf.predict(X_test)
accuracy=accuracy_score(y_test, pred)
f1=f1_score(y_test, pred)
recall=recall_score(y_test,pred)

print(accuracy)
print(f1)
print(recall)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9129643117261471
# 0.5191146881287727
# 0.4170258620689655

# %%
#SGboost

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb

def ML_pipeline_kfold_GridSearchCV(X_s,y,random_state,n_folds):
    # create a test set
    X_other, X_test, y_other, y_test = train_test_split(X_s, y, test_size=0.2, random_state = random_state,stratify=y)
    # splitter for _other
    kf = StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=random_state)
    # create the pipeline: preprocessor + supervised ML method
    xgb_model = xgb.XGBClassifier()
    # the parameter(s) we want to tune
    param_grid = {'learning_rate': [0.05,0.1,0.2],'max_depth': [2,4],'n_estimators': [5,10,20]}
    # prepare gridsearch
    grid = GridSearchCV(xgb_model, param_grid=param_grid,scoring = make_scorer(accuracy_score),
                        cv=kf, return_train_score = True,iid=True)
    # do kfold CV on _other
    grid.fit(X_other, y_other)
    return grid, grid.score(X_test, y_test)
test_scores = []
for i in range(5):
    grid, test_score = ML_pipeline_kfold_GridSearchCV(X,y,i*42,5)
    print(grid.best_params_)
    print('best CV score:',grid.best_score_)
    print('test score:',test_score)
    test_scores.append(test_score)
print('test accuracy:',np.around(np.mean(test_scores),2),'+/-',np.around(np.std(test_scores),4))
# Out:
# {'learning_rate': 0.2, 'max_depth': 4, 'n_estimators': 20}
# best CV score: 0.9150531107738998
# test score: 0.9145423646516144
# {'learning_rate': 0.2, 'max_depth': 4, 'n_estimators': 20}
# best CV score: 0.9139908952959028
# test score: 0.9201262442340374
# {'learning_rate': 0.2, 'max_depth': 4, 'n_estimators': 20}
# best CV score: 0.915144157814871
# test score: 0.915270696771061
# {'learning_rate': 0.2, 'max_depth': 4, 'n_estimators': 20}
# best CV score: 0.9151745068285281
# test score: 0.9170915270696771
# {'learning_rate': 0.2, 'max_depth': 4, 'n_estimators': 20}
# best CV score: 0.9143854324734446
# test score: 0.9183054139354212
# test accuracy: 0.92 +/- 0.002

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb

def ML_pipeline_kfold_GridSearchCV(X_s,y,random_state,n_folds):
    # create a test set
    X_other, X_test, y_other, y_test = train_test_split(X_s, y, test_size=0.2, random_state = random_state,stratify=y)
    # splitter for _other
    kf = StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=random_state)
    # create the pipeline: preprocessor + supervised ML method
    xgb_model = xgb.XGBClassifier()
    # the parameter(s) we want to tune
    param_grid = {'learning_rate': [0.05,0.1,0.2],'max_depth': [2,4],'n_estimators': [5,10,20]}
    # prepare gridsearch
    grid = GridSearchCV(xgb_model, param_grid=param_grid,scoring = make_scorer(recall_score),
                        cv=kf, return_train_score = True,iid=True)
    # do kfold CV on _other
    grid.fit(X_other, y_other)
    return grid, grid.score(X_test, y_test)
test_scores = []
for i in range(5):
    grid, test_score = ML_pipeline_kfold_GridSearchCV(X,y,i*42,5)
    print(grid.best_params_)
    print('best CV score:',grid.best_score_)
    print('test score:',test_score)
    test_scores.append(test_score)
print('test recall_score:',np.around(np.mean(test_scores),2),'+/-',np.around(np.std(test_scores),4))
# Out:
# {'learning_rate': 0.2, 'max_depth': 4, 'n_estimators': 20}
# best CV score: 0.4935347786415314
# test score: 0.5118534482758621
# {'learning_rate': 0.2, 'max_depth': 4, 'n_estimators': 20}
# best CV score: 0.4765642504389645
# test score: 0.4989224137931034
# {'learning_rate': 0.2, 'max_depth': 4, 'n_estimators': 20}
# best CV score: 0.48787981340068276
# test score: 0.47629310344827586
# {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 5}
# best CV score: 0.5196859397907995
# test score: 0.5538793103448276
# {'learning_rate': 0.2, 'max_depth': 4, 'n_estimators': 20}
# best CV score: 0.4819389948856275
# test score: 0.521551724137931
# test recall_score: 0.51 +/- 0.0257

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 1,stratify=y)
clf = xgb.XGBClassifier(learning_rate = 0.2, max_depth = 4, n_estimators = 20)
clf.fit(X_train,y_train)
pred = clf.predict(X_test)
accuracy=accuracy_score(y_test, pred)
f1=f1_score(y_test, pred)
recall=recall_score(y_test,pred)

print(accuracy)
print(f1)
print(recall)
# Out:
# 0.915270696771061
# 0.5738705738705738
# 0.5064655172413793

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
plot_importance(clf)
plt.figure(figsize=(10,10))
plt.show()

# %%
X_s
# Out:
#        job_admin.  job_blue-collar  job_entrepreneur  job_housemaid  \
# 0       -0.582023        -0.538317         -0.191430       6.152772
# 1       -0.582023        -0.538317         -0.191430      -0.162528
# 2       -0.582023        -0.538317         -0.191430      -0.162528
# 3        1.718146        -0.538317         -0.191430      -0.162528
# 4       -0.582023        -0.538317         -0.191430      -0.162528
# 5       -0.582023        -0.538317         -0.191430      -0.162528
# 6        1.718146        -0.538317         -0.191430      -0.162528
# 7       -0.582023         1.857642         -0.191430      -0.162528
# 8       -0.582023        -0.538317         -0.191430      -0.162528
# 9       -0.582023        -0.538317         -0.191430      -0.162528
# 10      -0.582023         1.857642         -0.191430      -0.162528
# 11      -0.582023        -0.538317         -0.191430      -0.162528
# 12      -0.582023         1.857642         -0.191430      -0.162528
# ...

# %%
#logistic global feature inportance

# %%
X_s
# Out:
#        job_admin.  job_blue-collar  job_entrepreneur  job_housemaid  \
# 0       -0.582023        -0.538317         -0.191430       6.152772
# 1       -0.582023        -0.538317         -0.191430      -0.162528
# 2       -0.582023        -0.538317         -0.191430      -0.162528
# 3        1.718146        -0.538317         -0.191430      -0.162528
# 4       -0.582023        -0.538317         -0.191430      -0.162528
# 5       -0.582023        -0.538317         -0.191430      -0.162528
# 6        1.718146        -0.538317         -0.191430      -0.162528
# 7       -0.582023         1.857642         -0.191430      -0.162528
# 8       -0.582023        -0.538317         -0.191430      -0.162528
# 9       -0.582023        -0.538317         -0.191430      -0.162528
# 10      -0.582023         1.857642         -0.191430      -0.162528
# 11      -0.582023        -0.538317         -0.191430      -0.162528
# 12      -0.582023         1.857642         -0.191430      -0.162528
# ...

# %%
X_s.columns
ftrs = ['job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
       'job_management', 'job_retired', 'job_self-employed', 'job_services',
       'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'education_basic.4y', 'education_basic.6y',
       'education_basic.9y', 'education_high.school', 'education_illiterate',
       'education_professional.course', 'education_university.degree',
       'education_unknown', 'default_no', 'default_unknown', 'default_yes',
       'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
       'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
       'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success',
       'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun',
       'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
       'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu',
       'day_of_week_tue', 'day_of_week_wed', 'pdayscon', 'age', 'campaign',
       'previous', 'duration', 'cons.price.idx', 'cons.conf.idx', 'euribor3m']

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

def ML_pipeline_kfold_GridSearchCV(X,y,random_state,n_folds):
    # create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state = random_state,stratify=y)
    # splitter for _other
    kf = StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=random_state)
    # create the pipeline: preprocessor + supervised ML method
    pipe = LogisticRegression()
    # the parameter(s) we want to tune
    param_grid = {'C': np.logspace(-1,1,num=3),'penalty': ['l1','l2']}
    # prepare gridsearch
    grid = GridSearchCV(pipe, param_grid=param_grid,scoring = make_scorer(accuracy_score),
                        cv=kf, return_train_score = True,iid=True)
    # do kfold CV on _other
    grid.fit(X_other, y_other)
    feature_names = ftrs
    return grid,np.array(feature_names), X_test, y_test

# %%
grid, feature_names, X_test, y_test = ML_pipeline_kfold_GridSearchCV(X_s,y,42,4)
#print('test score:',grid.score(X_test,y_test))
#coefs = grid.best_estimator_[-1].coef_[0]
#sorted_indcs = np.argsort(np.abs(coefs))

#plt.rcParams.update({'font.size': 14})
#plt.barh(np.arange(10),coefs[sorted_indcs[-10:]])
#plt.yticks(np.arange(10),feature_names[sorted_indcs[-10:]])
#plt.xlabel('coefficient')
#plt.title('all scaled')
#plt.tight_layout()
#plt.savefig('figures/LR_coefs_scaled.png',dpi=300)
#plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
import shap
shap.initjs() # required for visualizations later on
# create the explainer object with the random forest model
explainer = shap.TreeExplainer(grid.best_estimator_[1])
# transform the test set
X_test_transformed = grid.best_estimator_[0].transform(X_test)
print(np.shape(X_test_transformed))
# calculate shap values on the first 1000 points in the test
shap_values = explainer.shap_values(X_test_transformed[:1000])
print(np.shape(shap_values))

# %%
df
# Out:
#        age            job   marital            education  default  housing  \
# 0       56      housemaid   married             basic.4y       no       no
# 1       57       services   married          high.school  unknown       no
# 2       37       services   married          high.school       no      yes
# 3       40         admin.   married             basic.6y       no       no
# 4       56       services   married          high.school       no       no
# 5       45       services   married             basic.9y  unknown       no
# 6       59         admin.   married  professional.course       no       no
# 7       41    blue-collar   married              unknown  unknown       no
# 8       24     technician    single  professional.course       no      yes
# 9       25       services    single          high.school       no      yes
# 10      41    blue-collar   married              unknown  unknown       no
# ...

# %%
cat_ftrs_in = ['job','marital','education','default','housing','loan','contact','poutcome','month','day_of_week']
num_ftrs_in = ['pdayscon','age','campaign','previous','duration','cons.price.idx','cons.conf.idx','euribor3m']

# %%
t =cat_ftrs_in+num_ftrs_in

# %%
X_f=df[t]
X_f.shape
# Out:
# (41188, 18)

# %%
df_cat_nonpre = df[cat_ftrs]
df_num_nonpre = df[num_ftrs]
X_nonpreprocessed = pd.concat([df_cat_nonpre,df_num_nonpre],axis=1)
X_nonpreprocessed.shape
# Out:
# (41188, 18)

# %%
def ML_pipeline_kfold(X,y,random_state,n_folds):
    # create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state = random_state)
    # splitter for _other
    kf = StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=random_state)
    # create the pipeline: preprocessor + supervised ML method
    cat_ftrs = ['job','marital','education','default','housing','loan','contact','poutcome','month','day_of_week']
    num_ftrs = ['pdayscon','age','campaign','previous','duration','cons.price.idx','cons.conf.idx','euribor3m']
    # one-hot encoder
    categorical_transformer = Pipeline(steps=[
        ('onehot', OneHotEncoder(sparse=False,handle_unknown='ignore'))])
    # standard scaler
    numeric_transformer = Pipeline(steps=[
        ('scaler', StandardScaler())])
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, num_ftrs),
            ('cat', categorical_transformer, cat_ftrs)])
    pipe = make_pipeline(preprocessor,RandomForestClassifier(n_estimators =  100,random_state=random_state))
    # the parameter(s) we want to tune
    param_grid = {'randomforestclassifier__max_depth': [10,30,100,300],
                  'randomforestclassifier__min_samples_split': [16, 32, 64, 128]}
    # prepare gridsearch
    grid = GridSearchCV(pipe, param_grid=param_grid,cv=kf, return_train_score = True,n_jobs=-1,verbose=10)
    # do kfold CV on _other
    grid.fit(X_other, y_other)
    feature_names = num_ftrs + \
                list(grid.best_estimator_[0].named_transformers_['cat'][0].get_feature_names(cat_ftrs))
    return grid, np.array(feature_names), X_test, y_test

# %%
grid, feature_names, X_test, y_test = ML_pipeline_kfold(X_nonpreprocessed,y,42,4)
print(grid.best_score_)
print(grid.score(X_test,y_test))
print(grid.best_params_)
